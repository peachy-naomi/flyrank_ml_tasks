# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/peachy-naomi/flyrank_ml_tasks/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My task is a Binary Classification task.
# Why? I am categorizing every page into one of two buckets: "Requires Refresh" (1) or "Stable/Growing" (0). While we will eventually rank these by probability, the core task is identifying the signal of decline

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I am predicting a proxy target named is_declining.
# Source: This label comes from the trend_direction column in our historical data. If the direction is down, we label it 1 (needs refresh). This is an observed outcome from the data, serving as a proxy for the human decision that a page has "decayed" and requires attention.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My primary success metric is Precision@50.
# Defense: Editorial resources (writers) are expensive. If my model generates a list of 50 pages to fix, the Head of SEO needs to know that those pages are actually failing. High precision means we minimize "False Positives"—we don't want to waste money rewriting a page that is actually performing well. A score of 0.70 or higher would be considered "good" for this task.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, subprocess
import pandas as pd

# 1. Setup: Ensure we have the data
REPO_URL = "https://github.com/peachy-naomi/flyrank_ml_tasks"
REPO_DIR = "flyrank_ml_tasks"
if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL])
os.chdir(REPO_DIR)

# 2. Load the data
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 3. Create the target 'label'
df['is_declining'] = (df['trend_direction'] == 'down').astype(int)

# 4. Show the unit of analysis
# One row = One unique Page (URL)
unit_of_analysis = df[['content_id', 'search_volume', 'avg_position', 'ctr', 'is_declining']].head(5)
unit_of_analysis
# Out:
#              content_id  search_volume  avg_position   ctr  is_declining
# 0  content_304f48230142           10.0          10.6  0.76             1
# 1  content_a1fb4e703a9e           90.0          20.3  0.05             1
# 2  content_9aa793d4d895            0.0          36.5  0.09             1
# 3  content_331d6c4de07b           10.0           6.2  0.49             0
# 4  content_d99b7a2d90ca            0.0          44.0  0.13             1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# For Heads of SEO, deciding which pages to prioritize for a content refresh, we will build a Binary Classifier from FlyRank search data, predicting the is_declining label measured by Precision@50. A wrong call costs wasted editorial budget on healthy pages (False Positive) or permanent traffic loss on ignored pages (False Negative). A plain rule isn't enough because search decline signals are tangled across position, CTR, and competition metrics over time. We will claim only observed, directional, and decision-support results.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
