# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/peachy-naomi/flyrank_ml_tasks/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I am choosing Lane 1: Content Refresh (Predicting Declining Trends).
# Why? Our initial experiments showed that manual SEO rules are only ~24% accurate at identifying which pages are actually losing traffic. With over 30,000 pages in the sample, a human cannot manually audit every page. There is a clear need for a machine learning model that can prioritize pages for a refresh before the traffic loss becomes permanent.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The Decision: "Should we spend editorial budget to update this specific page today?"
# The Action: Adding the page to the high-priority "Editorial Refresh Queue" for a writer.
# The Cost of a Wrong Call: A False Positive wastes budget on healthy pages. A False Negative ignores a dying page, resulting in permanent loss of rankings and revenue.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os, subprocess
import pandas as pd

# 1. Setup: Clone the repo so Colab can find the data
REPO_URL = "https://github.com/peachy-naomi/flyrank_ml_tasks"
REPO_DIR = "flyrank_ml_tasks"
if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL])
os.chdir(REPO_DIR)

# 2. Load the data
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 3. Show 2 real numbers
total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])
print(f"Real Number 1 (Scale): Total pages in dataset: {total_pages:,}")
print(f"Real Number 2 (Need): {declining_pages:,} pages are currently declining ({declining_pages/total_pages:.1%}).")
# Out:
# Real Number 1 (Scale): Total pages in dataset: 30,000
# Real Number 2 (Need): 16,262 pages are currently declining (54.2%).

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I will use directional language. I am not claiming to "prove" why Google ranks pages. Instead, I will state that the model "identifies patterns associated with historical decline" to support human decision-making.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
